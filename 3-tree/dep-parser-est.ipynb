# %% [markdown]
# # Transition-based arc-eager unlabeled dependency parser for Estonian

# %% [markdown]
# ## Read the data
#
# To prepare the training data for the parser, we will be using:
# * [UD corpus for Estonian](https://github.com/UniversalDependencies/UD_Estonian-EDT)
# * [Easy-to-use library for parsing UD](https://github.com/EmilStenstrom/conllu)

# %%
from collections import OrderedDict
from conllu import parse
from enum import Enum

PATH = "UD_Estonian-EDT"

with open(PATH + "/et_edt-ud-train.conllu", "r") as f:
    data = f.read()

trees = parse(data)

# %%
tree = trees[0]
print(tree[0])
# Out:
# OrderedDict([('id', 1), ('form', 'Iga'), ('lemma', 'iga'), ('upostag', 'DET'), ('xpostag', 'P'), ('feats', OrderedDict([('Case', 'Nom'), ('Number', 'Sing'), ('PronType', 'Tot')])), ('head', 3), ('deprel', 'det'), ('deps', None), ('misc', None)])

# %%
# Every ninth crown came from mysterious people.
" ".join([node["form"] for node in tree])
# Out:
# 'Iga üheksas kroon tuli salapärastelt isikutelt .'

# %%
for node in tree:
    head = node["head"]
    print("{} <-- {}".format(node["form"],
                             tree[head - 1]["form"]
                             if head > 0 else "root"))
# Out:
# Iga <-- kroon
# üheksas <-- kroon
# kroon <-- tuli
# tuli <-- root
# salapärastelt <-- isikutelt
# isikutelt <-- tuli
# . <-- tuli

# %% [markdown]
# ## Design actions and the oracle
#
# We will be using a static oracle that reproduces a single valid order of actions.

# %%
class Actions(str, Enum):
    SHIFT = "shift"
    REDUCE = "reduce"
    RIGHT = "right"
    LEFT = "left"

# %%
def oracle(stack, top_queue, relations):
    """
    Make a decision on the right action to do.
    """
    top_stack = stack[-1]
    # check if both stack and queue are non-empty
    if top_stack and not top_queue:
        return Actions.REDUCE
    # check if there are any clear dependencies
    elif top_queue["head"] == top_stack["id"]:
        return Actions.RIGHT
    elif top_stack["head"] == top_queue["id"]:
        return Actions.LEFT
    # check if we can reduce the top of the stack
    elif top_stack["id"] in [i[0] for i in relations] and \
         (top_queue["head"] < top_stack["id"] or \
          [s for s in stack if s["head"] == top_queue["id"]]):
        return Actions.REDUCE
    # default option
    else:
        return Actions.SHIFT

# %%
ROOT = OrderedDict([('id', 0), ('form', 'ROOT'), ('lemma', 'ROOT'),
                    ('upostag', 'ROOT'), ('xpostag', None),
                    ('feats', None), ('head', None), ('deprel', None),
                    ('deps', None), ('misc', None)])

def trace_actions(tree, log=True):
    """
    Try out the oracle to verify it's returning the right actions.
    """
    stack, queue, relations = [ROOT], tree[:], []
    while queue or stack:
        action = oracle(stack if len(stack) > 0 else None,
                        queue[0] if len(queue) > 0 else None,
                        relations)
        if log:
            print("Stack:", [i["form"]+"_"+str(i["id"]) for i in stack])
            print("Queue:", [i["form"]+"_"+str(i["id"]) for i in queue])
            print("Relations:", relations)
            print(action)
            print("========================")
        if action == Actions.SHIFT:
            stack.append(queue.pop(0))
        elif action == Actions.REDUCE:
            stack.pop()
        elif action == Actions.LEFT:
            relations.append((stack[-1]["id"], queue[0]["id"]))
            stack.pop()
        elif action == Actions.RIGHT:
            relations.append((queue[0]["id"], stack[-1]["id"]))
            stack.append(queue.pop(0))
        else:
            print("Unknown action.")
    if log:
        print("Gold relations:")
        print([(node["id"], node["head"]) for node in tree])
        print("Retrieved relations:")
        print(sorted(relations))

trace_actions(tree)
# Out:
# Stack: ['ROOT_0']
# Queue: ['Iga_1', 'üheksas_2', 'kroon_3', 'tuli_4', 'salapärastelt_5', 'isikutelt_6', '._7']
# Relations: []
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'Iga_1']
# Queue: ['üheksas_2', 'kroon_3', 'tuli_4', 'salapärastelt_5', 'isikutelt_6', '._7']
# Relations: []
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'Iga_1', 'üheksas_2']
# Queue: ['kroon_3', 'tuli_4', 'salapärastelt_5', 'isikutelt_6', '._7']
# Relations: []
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'Iga_1']
# Queue: ['kroon_3', 'tuli_4', 'salapärastelt_5', 'isikutelt_6', '._7']
# Relations: [(2, 3)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0']
# Queue: ['kroon_3', 'tuli_4', 'salapärastelt_5', 'isikutelt_6', '._7']
# Relations: [(2, 3), (1, 3)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'kroon_3']
# Queue: ['tuli_4', 'salapärastelt_5', 'isikutelt_6', '._7']
# Relations: [(2, 3), (1, 3)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0']
# Queue: ['tuli_4', 'salapärastelt_5', 'isikutelt_6', '._7']
# Relations: [(2, 3), (1, 3), (3, 4)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'tuli_4']
# Queue: ['salapärastelt_5', 'isikutelt_6', '._7']
# Relations: [(2, 3), (1, 3), (3, 4), (4, 0)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'tuli_4', 'salapärastelt_5']
# Queue: ['isikutelt_6', '._7']
# Relations: [(2, 3), (1, 3), (3, 4), (4, 0)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'tuli_4']
# Queue: ['isikutelt_6', '._7']
# Relations: [(2, 3), (1, 3), (3, 4), (4, 0), (5, 6)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'tuli_4', 'isikutelt_6']
# Queue: ['._7']
# Relations: [(2, 3), (1, 3), (3, 4), (4, 0), (5, 6), (6, 4)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'tuli_4']
# Queue: ['._7']
# Relations: [(2, 3), (1, 3), (3, 4), (4, 0), (5, 6), (6, 4)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'tuli_4', '._7']
# Queue: []
# Relations: [(2, 3), (1, 3), (3, 4), (4, 0), (5, 6), (6, 4), (7, 4)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'tuli_4']
# Queue: []
# Relations: [(2, 3), (1, 3), (3, 4), (4, 0), (5, 6), (6, 4), (7, 4)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0']
# Queue: []
# Relations: [(2, 3), (1, 3), (3, 4), (4, 0), (5, 6), (6, 4), (7, 4)]
# Actions.REDUCE
# ========================
# Gold relations:
# [(1, 3), (2, 3), (3, 4), (4, 0), (5, 6), (6, 4), (7, 4)]
# Retrieved relations:
# [(1, 3), (2, 3), (3, 4), (4, 0), (5, 6), (6, 4), (7, 4)]

# %%
trace_actions(trees[1])
# Out:
# Stack: ['ROOT_0']
# Queue: ['Eesti_1', 'Ekspressi_2', 'teada_3', 'on_4', 'Eesti_5', 'Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: []
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'Eesti_1']
# Queue: ['Ekspressi_2', 'teada_3', 'on_4', 'Eesti_5', 'Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: []
# Actions.LEFT
# ========================
# Stack: ['ROOT_0']
# Queue: ['Ekspressi_2', 'teada_3', 'on_4', 'Eesti_5', 'Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'Ekspressi_2']
# Queue: ['teada_3', 'on_4', 'Eesti_5', 'Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0']
# Queue: ['teada_3', 'on_4', 'Eesti_5', 'Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'teada_3']
# Queue: ['on_4', 'Eesti_5', 'Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'teada_3', 'on_4']
# Queue: ['Eesti_5', 'Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'teada_3', 'on_4', 'Eesti_5']
# Queue: ['Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'teada_3', 'on_4']
# Queue: ['Pank_6', 'uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'teada_3', 'on_4', 'Pank_6']
# Queue: ['uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'teada_3', 'on_4']
# Queue: ['uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'teada_3']
# Queue: ['uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0']
# Queue: ['uurinud_7', 'Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7']
# Queue: ['Hansapanga_8', 'tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'Hansapanga_8']
# Queue: ['tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7']
# Queue: ['tehinguid_9', ',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9']
# Queue: [',_10', 'mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', ',_10']
# Queue: ['mis_11', 'toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', ',_10', 'mis_11']
# Queue: ['toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', ',_10']
# Queue: ['toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9']
# Queue: ['toimusid_12', 'kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12']
# Queue: ['kaks_13', 'aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'kaks_13']
# Queue: ['aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12']
# Queue: ['aastat_14', 'tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'aastat_14']
# Queue: ['tagasi_15', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'aastat_14', 'tagasi_15']
# Queue: ['suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'aastat_14']
# Queue: ['suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12']
# Queue: ['suvel_16', 'ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16']
# Queue: ['ja_17', 'mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'ja_17']
# Queue: ['mille_18', 'käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'ja_17', 'mille_18']
# Queue: ['käigus_19', 'voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'ja_17', 'mille_18', 'käigus_19']
# Queue: ['voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'ja_17', 'mille_18']
# Queue: ['voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'ja_17']
# Queue: ['voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16']
# Queue: ['voolas_20', 'panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20']
# Queue: ['panka_21', 'ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'panka_21']
# Queue: ['ligi_22', 'miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'panka_21', 'ligi_22']
# Queue: ['miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'panka_21']
# Queue: ['miljardi_23', 'krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'panka_21', 'miljardi_23']
# Queue: ['krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'panka_21']
# Queue: ['krooni_24', 'ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'panka_21', 'krooni_24']
# Queue: ['ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'panka_21']
# Queue: ['ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20']
# Queue: ['ulatuses_25', 'kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'ulatuses_25']
# Queue: ['kahtlast_26', 'raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20)]
# Actions.SHIFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'ulatuses_25', 'kahtlast_26']
# Queue: ['raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20)]
# Actions.LEFT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'ulatuses_25']
# Queue: ['raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20']
# Queue: ['raha_27', '._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20', 'raha_27']
# Queue: ['._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16', 'voolas_20']
# Queue: ['._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12', 'suvel_16']
# Queue: ['._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9', 'toimusid_12']
# Queue: ['._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7', 'tehinguid_9']
# Queue: ['._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7']
# Queue: ['._28']
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20)]
# Actions.RIGHT
# ========================
# Stack: ['ROOT_0', 'uurinud_7', '._28']
# Queue: []
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20), (28, 7)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0', 'uurinud_7']
# Queue: []
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20), (28, 7)]
# Actions.REDUCE
# ========================
# Stack: ['ROOT_0']
# Queue: []
# Relations: [(1, 2), (2, 3), (4, 3), (5, 6), (6, 7), (3, 7), (7, 0), (8, 9), (9, 7), (11, 12), (10, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (19, 18), (18, 20), (17, 20), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20), (28, 7)]
# Actions.REDUCE
# ========================
# Gold relations:
# [(1, 2), (2, 3), (3, 7), (4, 3), (5, 6), (6, 7), (7, 0), (8, 9), (9, 7), (10, 12), (11, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (17, 20), (18, 20), (19, 18), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20), (28, 7)]
# Retrieved relations:
# [(1, 2), (2, 3), (3, 7), (4, 3), (5, 6), (6, 7), (7, 0), (8, 9), (9, 7), (10, 12), (11, 12), (12, 9), (13, 14), (14, 12), (15, 14), (16, 12), (17, 20), (18, 20), (19, 18), (20, 16), (21, 20), (22, 23), (23, 24), (24, 25), (25, 20), (26, 27), (27, 20), (28, 7)]

# %% [markdown]
# ## Feature extraction
#
# Reference: [Dependency Parsing by Kübler, McDonald, and Nivre](https://books.google.com.ua/books?id=k3iiup7HB9UC&pg=PA21&hl=uk&source=gbs_toc_r&cad=4#v=onepage&q&f=false)

# %%
def extract_features(stack, queue):
    features = dict()
    if len(stack) > 0:
        stack_top = stack[-1]
        features["s0-word"] = stack_top["form"]
        features["s0-lemma"] = stack_top["lemma"]
        features["s0-tag"] = stack_top["upostag"]
    if len(stack) > 1:
        features["s1-tag"] = stack[-2]["upostag"]
    if queue:
        queue_top = queue[0]
        features["q0-word"] = queue_top["form"]
        features["q0-lemma"] = queue_top["lemma"]
        features["q0-tag"] = queue_top["upostag"]
    if len(queue) > 1:
        queue_next = queue[1]
        features["q1-word"] = queue_next["form"]
        features["q1-tag"] = queue_next["upostag"]
    if len(queue) > 2:
        features["q2-tag"] = queue[2]["upostag"]
    if len(queue) > 3:
        features["q3-tag"] = queue[3]["upostag"]
    return features

# %% [markdown]
# ## Prepare train and test data

# %%
def get_data(tree):
    features, labels = [], []
    stack, queue, relations = [ROOT], tree[:], []

    while queue or stack:
        action = oracle(stack if len(stack) > 0 else None,
                        queue[0] if len(queue) > 0 else None,
                        relations)
        features.append(extract_features(stack, queue))
        labels.append(action.value)
        if action == Actions.SHIFT:
            stack.append(queue.pop(0))
        elif action == Actions.REDUCE:
            stack.pop()
        elif action == Actions.LEFT:
            relations.append((stack[-1]["id"], queue[0]["id"]))
            stack.pop()
        elif action == Actions.RIGHT:
            relations.append((queue[0]["id"], stack[-1]["id"]))
            stack.append(queue.pop(0))
        else:
            print("Unknown action.")
    return features, labels

# %%
features, labels = get_data(tree)
print("Number of words:", len(tree))
print("Number of actions:", len(labels))
print("List of actions taken:", labels)
print("Features:")
for word in features:
    print(word)
# Out:
# Number of words: 7
# Number of actions: 15
# List of actions taken: ['shift', 'shift', 'left', 'left', 'shift', 'left', 'right', 'shift', 'left', 'right', 'reduce', 'right', 'reduce', 'reduce', 'reduce']
# Features:
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 'q0-word': 'Iga', 'q0-lemma': 'iga', 'q0-tag': 'DET', 'q1-word': 'üheksas', 'q1-tag': 'ADJ', 'q2-tag': 'NOUN', 'q3-tag': 'VERB'}
# {'s0-word': 'Iga', 's0-lemma': 'iga', 's0-tag': 'DET', 's1-tag': 'ROOT', 'q0-word': 'üheksas', 'q0-lemma': 'üheksas', 'q0-tag': 'ADJ', 'q1-word': 'kroon', 'q1-tag': 'NOUN', 'q2-tag': 'VERB', 'q3-tag': 'ADJ'}
# {'s0-word': 'üheksas', 's0-lemma': 'üheksas', 's0-tag': 'ADJ', 's1-tag': 'DET', 'q0-word': 'kroon', 'q0-lemma': 'kroon', 'q0-tag': 'NOUN', 'q1-word': 'tuli', 'q1-tag': 'VERB', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'Iga', 's0-lemma': 'iga', 's0-tag': 'DET', 's1-tag': 'ROOT', 'q0-word': 'kroon', 'q0-lemma': 'kroon', 'q0-tag': 'NOUN', 'q1-word': 'tuli', 'q1-tag': 'VERB', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 'q0-word': 'kroon', 'q0-lemma': 'kroon', 'q0-tag': 'NOUN', 'q1-word': 'tuli', 'q1-tag': 'VERB', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'kroon', 's0-lemma': 'kroon', 's0-tag': 'NOUN', 's1-tag': 'ROOT', 'q0-word': 'tuli', 'q0-lemma': 'tulema', 'q0-tag': 'VERB', 'q1-word': 'salapärastelt', 'q1-tag': 'ADJ', 'q2-tag': 'NOUN', 'q3-tag': 'PUNCT'}
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 'q0-word': 'tuli', 'q0-lemma': 'tulema', 'q0-tag': 'VERB', 'q1-word': 'salapärastelt', 'q1-tag': 'ADJ', 'q2-tag': 'NOUN', 'q3-tag': 'PUNCT'}
# {'s0-word': 'tuli', 's0-lemma': 'tulema', 's0-tag': 'VERB', 's1-tag': 'ROOT', 'q0-word': 'salapärastelt', 'q0-lemma': 'sala_pärane', 'q0-tag': 'ADJ', 'q1-word': 'isikutelt', 'q1-tag': 'NOUN', 'q2-tag': 'PUNCT'}
# {'s0-word': 'salapärastelt', 's0-lemma': 'sala_pärane', 's0-tag': 'ADJ', 's1-tag': 'VERB', 'q0-word': 'isikutelt', 'q0-lemma': 'isik', 'q0-tag': 'NOUN', 'q1-word': '.', 'q1-tag': 'PUNCT'}
# {'s0-word': 'tuli', 's0-lemma': 'tulema', 's0-tag': 'VERB', 's1-tag': 'ROOT', 'q0-word': 'isikutelt', 'q0-lemma': 'isik', 'q0-tag': 'NOUN', 'q1-word': '.', 'q1-tag': 'PUNCT'}
# {'s0-word': 'isikutelt', 's0-lemma': 'isik', 's0-tag': 'NOUN', 's1-tag': 'VERB', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT'}
# {'s0-word': 'tuli', 's0-lemma': 'tulema', 's0-tag': 'VERB', 's1-tag': 'ROOT', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT'}
# {'s0-word': '.', 's0-lemma': '.', 's0-tag': 'PUNCT', 's1-tag': 'VERB'}
# {'s0-word': 'tuli', 's0-lemma': 'tulema', 's0-tag': 'VERB', 's1-tag': 'ROOT'}
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT'}

# %%
train_features, train_labels = [], []
for tree in trees:
    tree_features, tree_labels = get_data(tree)
    train_features += tree_features
    train_labels += tree_labels

print(len(train_features), len(train_labels))
# Out:
# 706628 706628

# %%
# Test data

with open(PATH + "/et_edt-ud-dev.conllu", "r") as f:
    data = f.read()
test_trees = parse(data)

test_features, test_labels = [], []
for tree in test_trees:
    tree_features, tree_labels = get_data(tree)
    test_features += tree_features
    test_labels += tree_labels

print(len(test_features), len(test_labels))
# Out:
# 92389 92389

# %% [markdown]
# ## Train a classifier

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
vectorizer = DictVectorizer()
vec = vectorizer.fit(train_features)

print("\nTotal number of features: ", len(vec.get_feature_names()))
# Out:
# Total number of features:  284211

# %%
train_features_vectorized = vec.transform(train_features)
test_features_vectorized = vec.transform(test_features)

print(len(train_features_vectorized.toarray()),
      len(test_features_vectorized.toarray()))
# Out:
# 706628 92389

# %%
lrc = LogisticRegression(random_state=42, solver="saga",
                         multi_class="multinomial", max_iter=1000,
                         verbose=1)
lrc.fit(train_features_vectorized, train_labels)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 507 epochs took 600 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed: 10.0min finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='multinomial',
#           n_jobs=None, penalty='l2', random_state=42, solver='saga',
#           tol=0.0001, verbose=1, warm_start=False)

# %%
predicted = lrc.predict(test_features_vectorized)
print(classification_report(test_labels, predicted))
# Out:
#               precision    recall  f1-score   support
#
#         left       0.81      0.84      0.83     24155
#       reduce       0.86      0.84      0.85     23602
#        right       0.82      0.78      0.80     20095
#        shift       0.82      0.84      0.83     24537
#
#    micro avg       0.83      0.83      0.83     92389
#    macro avg       0.83      0.83      0.83     92389
# weighted avg       0.83      0.83      0.83     92389

# %% [markdown]
# ## Calculate the unlabeled attachment score
# UAS - the percentage of words in an input that are assigned the correct head.

# %%
def dep_parse(sentence, oracle, vectorizer, log=True):
    stack, queue, relations = [ROOT], sentence[:], []
    while queue or stack:
        if stack and not queue:
            stack.pop()
        else:
            features = extract_features(stack, queue)
            action = oracle.predict(vectorizer.transform([features]))[0]
            if log:
                print("Stack:", [i["form"]+"_"+str(i["id"])
                                 for i in stack])
                print("Queue:", [i["form"]+"_"+str(i["id"])
                                 for i in queue])
                print("Relations:", relations)
                print(action)
                print("========================")
            # actual parsing
            if action == Actions.SHIFT:
                stack.append(queue.pop(0))
            elif action == Actions.REDUCE:
                stack.pop()
            elif action == Actions.LEFT:
                relations.append((stack[-1]["id"], queue[0]["id"]))
                stack.pop()
            elif action == Actions.RIGHT:
                relations.append((queue[0]["id"], stack[-1]["id"]))
                stack.append(queue.pop(0))
            else:
                print("Unknown action.")
    return sorted(relations)

# %%
print([node["form"] for node in test_trees[0]])
print(dep_parse(test_trees[0], lrc, vec))
print([(node["id"], node["head"]) for node in test_trees[0]])
# Out:
# ['Aga', 'mulle', 'tundub', ',', 'et', 'kogu', 'maailm', 'ootab', 'muusikamaailmalt', 'midagi', 'erutavalt', 'uut', 'minimalismi', 'kõrvale', '.']
# Stack: ['ROOT_0']
# Queue: ['Aga_1', 'mulle_2', 'tundub_3', ',_4', 'et_5', 'kogu_6', 'maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: []
# shift
# ========================
# Stack: ['ROOT_0', 'Aga_1']
# Queue: ['mulle_2', 'tundub_3', ',_4', 'et_5', 'kogu_6', 'maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: []
# shift
# ========================
# Stack: ['ROOT_0', 'Aga_1', 'mulle_2']
# Queue: ['tundub_3', ',_4', 'et_5', 'kogu_6', 'maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: []
# left
# ========================
# Stack: ['ROOT_0', 'Aga_1']
# Queue: ['tundub_3', ',_4', 'et_5', 'kogu_6', 'maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3)]
# left
# ========================
# Stack: ['ROOT_0']
# Queue: ['tundub_3', ',_4', 'et_5', 'kogu_6', 'maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3)]
# right
# ========================
# Stack: ['ROOT_0', 'tundub_3']
# Queue: [',_4', 'et_5', 'kogu_6', 'maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0)]
# shift
# ========================
# Stack: ['ROOT_0', 'tundub_3', ',_4']
# Queue: ['et_5', 'kogu_6', 'maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0)]
# shift
# ========================
# Stack: ['ROOT_0', 'tundub_3', ',_4', 'et_5']
# Queue: ['kogu_6', 'maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0)]
# shift
# ========================
# Stack: ['ROOT_0', 'tundub_3', ',_4', 'et_5', 'kogu_6']
# Queue: ['maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0)]
# left
# ========================
# Stack: ['ROOT_0', 'tundub_3', ',_4', 'et_5']
# Queue: ['maailm_7', 'ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7)]
# shift
# ========================
# Stack: ['ROOT_0', 'tundub_3', ',_4', 'et_5', 'maailm_7']
# Queue: ['ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7)]
# left
# ========================
# Stack: ['ROOT_0', 'tundub_3', ',_4', 'et_5']
# Queue: ['ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8)]
# left
# ========================
# Stack: ['ROOT_0', 'tundub_3', ',_4']
# Queue: ['ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8)]
# left
# ========================
# Stack: ['ROOT_0', 'tundub_3']
# Queue: ['ootab_8', 'muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8)]
# right
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8']
# Queue: ['muusikamaailmalt_9', 'midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3)]
# right
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'muusikamaailmalt_9']
# Queue: ['midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8)]
# reduce
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8']
# Queue: ['midagi_10', 'erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8)]
# right
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10']
# Queue: ['erutavalt_11', 'uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8)]
# right
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10', 'erutavalt_11']
# Queue: ['uut_12', 'minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10)]
# shift
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10', 'erutavalt_11', 'uut_12']
# Queue: ['minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10)]
# left
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10', 'erutavalt_11']
# Queue: ['minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10), (12, 13)]
# left
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10']
# Queue: ['minimalismi_13', 'kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10), (12, 13), (11, 13)]
# right
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10', 'minimalismi_13']
# Queue: ['kõrvale_14', '._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10), (12, 13), (11, 13), (13, 10)]
# right
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10', 'minimalismi_13', 'kõrvale_14']
# Queue: ['._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10), (12, 13), (11, 13), (13, 10), (14, 13)]
# reduce
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10', 'minimalismi_13']
# Queue: ['._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10), (12, 13), (11, 13), (13, 10), (14, 13)]
# reduce
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8', 'midagi_10']
# Queue: ['._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10), (12, 13), (11, 13), (13, 10), (14, 13)]
# reduce
# ========================
# Stack: ['ROOT_0', 'tundub_3', 'ootab_8']
# Queue: ['._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10), (12, 13), (11, 13), (13, 10), (14, 13)]
# reduce
# ========================
# Stack: ['ROOT_0', 'tundub_3']
# Queue: ['._15']
# Relations: [(2, 3), (1, 3), (3, 0), (6, 7), (7, 8), (5, 8), (4, 8), (8, 3), (9, 8), (10, 8), (11, 10), (12, 13), (11, 13), (13, 10), (14, 13)]
# right
# ========================
# [(1, 3), (2, 3), (3, 0), (4, 8), (5, 8), (6, 7), (7, 8), (8, 3), (9, 8), (10, 8), (11, 10), (11, 13), (12, 13), (13, 10), (14, 13), (15, 3)]
# [(1, 3), (2, 3), (3, 0), (4, 8), (5, 8), (6, 7), (7, 8), (8, 3), (9, 8), (10, 8), (11, 12), (12, 10), (13, 8), (14, 13), (15, 3)]

# %%
print([node["form"] for node in test_trees[3]])
print(dep_parse(test_trees[3], lrc, vec))
print([(node["id"], node["head"]) for node in test_trees[3]])
# Out:
# ['Godard', 'on', 'märkinud', ',', 'et', 'Vermeer', 'on', 'parimaid', 'fotograafe', 'kakssada', 'aastat', 'enne', 'fotokunsti', ',', 'sest', 'Vermeer', 'huvitus', 'tohutult', 'oskusest', 'vaadata', ',', 'ajahetke', 'jäädvustamisest', '.']
# Stack: ['ROOT_0']
# Queue: ['Godard_1', 'on_2', 'märkinud_3', ',_4', 'et_5', 'Vermeer_6', 'on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: []
# shift
# ========================
# Stack: ['ROOT_0', 'Godard_1']
# Queue: ['on_2', 'märkinud_3', ',_4', 'et_5', 'Vermeer_6', 'on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: []
# shift
# ========================
# Stack: ['ROOT_0', 'Godard_1', 'on_2']
# Queue: ['märkinud_3', ',_4', 'et_5', 'Vermeer_6', 'on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: []
# left
# ========================
# Stack: ['ROOT_0', 'Godard_1']
# Queue: ['märkinud_3', ',_4', 'et_5', 'Vermeer_6', 'on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3)]
# left
# ========================
# Stack: ['ROOT_0']
# Queue: ['märkinud_3', ',_4', 'et_5', 'Vermeer_6', 'on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3)]
# right
# ========================
# Stack: ['ROOT_0', 'märkinud_3']
# Queue: [',_4', 'et_5', 'Vermeer_6', 'on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4']
# Queue: ['et_5', 'Vermeer_6', 'on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4', 'et_5']
# Queue: ['Vermeer_6', 'on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4', 'et_5', 'Vermeer_6']
# Queue: ['on_7', 'parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4', 'et_5', 'Vermeer_6', 'on_7']
# Queue: ['parimaid_8', 'fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4', 'et_5', 'Vermeer_6', 'on_7', 'parimaid_8']
# Queue: ['fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4', 'et_5', 'Vermeer_6', 'on_7']
# Queue: ['fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4', 'et_5', 'Vermeer_6']
# Queue: ['fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4', 'et_5']
# Queue: ['fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', ',_4']
# Queue: ['fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3']
# Queue: ['fotograafe_9', 'kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9)]
# right
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotograafe_9']
# Queue: ['kakssada_10', 'aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotograafe_9', 'kakssada_10']
# Queue: ['aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotograafe_9']
# Queue: ['aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11)]
# reduce
# ========================
# Stack: ['ROOT_0', 'märkinud_3']
# Queue: ['aastat_11', 'enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11)]
# right
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'aastat_11']
# Queue: ['enne_12', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'aastat_11', 'enne_12']
# Queue: ['fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'aastat_11']
# Queue: ['fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13)]
# reduce
# ========================
# Stack: ['ROOT_0', 'märkinud_3']
# Queue: ['fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13)]
# right
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotokunsti_13']
# Queue: [',_14', 'sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotokunsti_13', ',_14']
# Queue: ['sest_15', 'Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotokunsti_13', ',_14', 'sest_15']
# Queue: ['Vermeer_16', 'huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotokunsti_13', ',_14', 'sest_15', 'Vermeer_16']
# Queue: ['huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotokunsti_13', ',_14', 'sest_15']
# Queue: ['huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotokunsti_13', ',_14']
# Queue: ['huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'fotokunsti_13']
# Queue: ['huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17)]
# reduce
# ========================
# Stack: ['ROOT_0', 'märkinud_3']
# Queue: ['huvitus_17', 'tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17)]
# right
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17']
# Queue: ['tohutult_18', 'oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'tohutult_18']
# Queue: ['oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17']
# Queue: ['oskusest_19', 'vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19)]
# right
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'oskusest_19']
# Queue: ['vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17)]
# reduce
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17']
# Queue: ['vaadata_20', ',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17)]
# right
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'vaadata_20']
# Queue: [',_21', 'ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'vaadata_20', ',_21']
# Queue: ['ajahetke_22', 'jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17)]
# shift
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'vaadata_20', ',_21', 'ajahetke_22']
# Queue: ['jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'vaadata_20', ',_21']
# Queue: ['jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17), (22, 23)]
# left
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'vaadata_20']
# Queue: ['jäädvustamisest_23', '._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17), (22, 23), (21, 23)]
# right
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'vaadata_20', 'jäädvustamisest_23']
# Queue: ['._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17), (22, 23), (21, 23), (23, 20)]
# reduce
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17', 'vaadata_20']
# Queue: ['._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17), (22, 23), (21, 23), (23, 20)]
# reduce
# ========================
# Stack: ['ROOT_0', 'märkinud_3', 'huvitus_17']
# Queue: ['._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17), (22, 23), (21, 23), (23, 20)]
# reduce
# ========================
# Stack: ['ROOT_0', 'märkinud_3']
# Queue: ['._24']
# Relations: [(2, 3), (1, 3), (3, 0), (8, 9), (7, 9), (6, 9), (5, 9), (4, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (16, 17), (15, 17), (14, 17), (17, 3), (18, 19), (19, 17), (20, 17), (22, 23), (21, 23), (23, 20)]
# right
# ========================
# [(1, 3), (2, 3), (3, 0), (4, 9), (5, 9), (6, 9), (7, 9), (8, 9), (9, 3), (10, 11), (11, 3), (12, 13), (13, 3), (14, 17), (15, 17), (16, 17), (17, 3), (18, 19), (19, 17), (20, 17), (21, 23), (22, 23), (23, 20), (24, 3)]
# [(1, 3), (2, 3), (3, 0), (4, 9), (5, 9), (6, 9), (7, 9), (8, 9), (9, 3), (10, 11), (11, 13), (12, 13), (13, 9), (14, 17), (15, 17), (16, 17), (17, 9), (18, 17), (19, 17), (20, 19), (21, 23), (22, 23), (23, 19), (24, 3)]

# %%
total, tp = 0, 0
for tree in test_trees:
    golden = [(node["id"], node["head"]) for node in tree]
    predicted = dep_parse(tree, lrc, vec, log=False)
    total += len(tree)
    tp += len(set(golden).intersection(set(predicted)))

print("Total:", total)
print("Correctly defined:", tp)
print("UAS:", round(tp/total, 2))
# Out:
# Total: 44632
# Correctly defined: 30272
# UAS: 0.68

# %% [markdown]
# ## Try on a new sentence

# %%
# I like turtles.
new_sentence = "Mulle meeldivad kilpkonnad .".split()
new_lemmas = "mina meeldima kilpkonn .".split()
new_pos = "PRON VERB NOUN PUNCT".split()

# %%
new_conll = []
for i, j in enumerate(zip(new_sentence, new_lemmas, new_pos)):
    word, lemma, tag = j
    new_conll.append(OrderedDict([('id', i+1), ('form', word),
                                  ('lemma', lemma), ('upostag', tag),
                                  ('xpostag', None), ('feats', None),
                                  ('head', None), ('deprel', None),
                                  ('deps', None), ('misc', None)]))

# %%
new_conll
# Out:
# [OrderedDict([('id', 1),
#               ('form', 'Mulle'),
#               ('lemma', 'mina'),
#               ('upostag', 'PRON'),
#               ('xpostag', None),
#               ('feats', None),
#               ('head', None),
#               ('deprel', None),
#               ('deps', None),
#               ('misc', None)]),
#  OrderedDict([('id', 2),
#               ('form', 'meeldivad'),
#               ('lemma', 'meeldima'),
#               ('upostag', 'VERB'),
#               ('xpostag', None),
#               ('feats', None),
#               ('head', None),
#               ('deprel', None),
#               ('deps', None),
#               ('misc', None)]),
#  OrderedDict([('id', 3),
#               ('form', 'kilpkonnad'),
#               ('lemma', 'kilpkonn'),
#               ('upostag', 'NOUN'),
#               ('xpostag', None),
#               ('feats', None),
#               ('head', None),
#               ('deprel', None),
#               ('deps', None),
#               ('misc', None)]),
#  OrderedDict([('id', 4),
#               ('form', '.'),
#               ('lemma', '.'),
#               ('upostag', 'PUNCT'),
#               ('xpostag', None),
#               ('feats', None),
#               ('head', None),
#               ('deprel', None),
#               ('deps', None),
#               ('misc', None)])]

# %%
dep_parse(new_conll, lrc, vec)
# Out:
# Stack: ['ROOT_0']
# Queue: ['Mulle_1', 'meeldivad_2', 'kilpkonnad_3', '._4']
# Relations: []
# shift
# ========================
# Stack: ['ROOT_0', 'Mulle_1']
# Queue: ['meeldivad_2', 'kilpkonnad_3', '._4']
# Relations: []
# left
# ========================
# Stack: ['ROOT_0']
# Queue: ['meeldivad_2', 'kilpkonnad_3', '._4']
# Relations: [(1, 2)]
# right
# ========================
# Stack: ['ROOT_0', 'meeldivad_2']
# Queue: ['kilpkonnad_3', '._4']
# Relations: [(1, 2), (2, 0)]
# right
# ========================
# Stack: ['ROOT_0', 'meeldivad_2', 'kilpkonnad_3']
# Queue: ['._4']
# Relations: [(1, 2), (2, 0), (3, 2)]
# reduce
# ========================
# Stack: ['ROOT_0', 'meeldivad_2']
# Queue: ['._4']
# Relations: [(1, 2), (2, 0), (3, 2)]
# right
# ========================
# [(1, 2), (2, 0), (3, 2), (4, 2)]

# %% [markdown]
# ### Your turn
# * Add a dependency label classifier to finalize the parser. Measure the LAS (labelled attachment score).
# * Add more features to improve the quality of the parser. Explore top features to understand if your classifiers are learning properly.
# * Add beam search or a non-deterministic oracle.
# * Compare your results with the parser from [estnltk](https://github.com/estnltk/estnltk).
# * Use [estnltk](https://github.com/estnltk/estnltk) for part-of-speech tagging and lemmatization of new sentences. Use your parser on new sentences.
